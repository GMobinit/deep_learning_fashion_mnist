# %% [markdown]
# <center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">به نام خدا</div></center>
#
# <h1><center><div style="direction:rtl;font-family:B Lotus, B Nazanin, Tahoma">رگرسیون تخمین قیمت خانه با چند ورودی<br>تصویر+داده های ساختار یافته
# </div></center></h1>

# %%
# import the necessary packages
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import glob
import cv2
import os
import locale

# %%
# !git clone https://github.com/emanhamed/Houses-dataset.git
# Out:
# Cloning into 'Houses-dataset'...
# remote: Enumerating objects: 2166, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2166 (delta 0), reused 0 (delta 0), pack-reused 2165 (from 1)
# Receiving objects: 100% (2166/2166), 176.26 MiB | 30.47 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# Updating files: 100% (2144/2144), done.

# %%
inputPath = "/content/Houses-dataset/Houses Dataset/HousesInfo.txt"
datasetPath = "/content/Houses-dataset/Houses Dataset"

cols = ["bedrooms", "bathrooms", "area", "zipcode", "price"]
df = pd.read_csv(inputPath, sep=" ", header=None, names=cols)


zipcodes, counts = np.unique(df["zipcode"], return_counts=True)

# loop over each of the unique zip codes and their corresponding
# count
for (zipcode, count) in zip(zipcodes, counts):
    # the zip code counts for our housing dataset is *extremely*
    # unbalanced (some only having 1 or 2 houses per zip code)
    # so let's sanitize our data by removing any houses with less
    # than 25 houses per zip code
    if count < 25:
        idxs = df[df["zipcode"] == zipcode].index
        df.drop(idxs, inplace=True)

# %%
# initialize our images array (i.e., the house images themselves)
images = []

# loop over the indexes of the houses
for i in df.index.values:
    # find the four images for the house and sort the file paths,
    # ensuring the four are always in the *same order*
    basePath = os.path.sep.join([datasetPath, "{}_*".format(i + 1)])
    housePaths = sorted(list(glob.glob(basePath)))
    # initialize our list of input images along with the output image
    # after *combining* the four input images
    inputImages = []
    outputImage = np.zeros((64, 64, 3), dtype="uint8")

    # loop over the input house paths
    for housePath in housePaths:
        # load the input image, resize it to be 32 32, and then
        # update the list of input images
        image = cv2.imread(housePath)
        image = cv2.resize(image, (32, 32))
        inputImages.append(image)

    # tile the four input images in the output image such the first
    # image goes in the top-right corner, the second image in the
    # top-left corner, the third image in the bottom-right corner,
    # and the final image in the bottom-left corner
    outputImage[0:32, 0:32] = inputImages[0]
    outputImage[0:32, 32:64] = inputImages[1]
    outputImage[32:64, 32:64] = inputImages[2]
    outputImage[32:64, 0:32] = inputImages[3]

    # add the tiled image to our set of images the network will be
    # trained on
    images.append(outputImage)
images = np.array(images)

# %%
images = images / 255.0

# %%
# partition the data into training and testing splits using 75% of
# the data for training and the remaining 25% for testing
split = train_test_split(df, images, test_size=0.25, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split

# %%
# find the largest house price in the training set and use it to
# scale our house prices to the range [0, 1] (will lead to better
# training and convergence)
maxPrice = trainAttrX["price"].max()
trainY = trainAttrX["price"] / maxPrice
testY = testAttrX["price"] / maxPrice

# %%
# initialize the column names of the continuous data
continuous = ["bedrooms", "bathrooms", "area"]

# performin min-max scaling each continuous feature column to
# the range [0, 1]
cs = MinMaxScaler()
trainContinuous = cs.fit_transform(trainAttrX[continuous])
testContinuous = cs.transform(testAttrX[continuous])

# one-hot encode the zip code categorical data (by definition of
# one-hot encoing, all output features are now in the range [0, 1])
zipBinarizer = LabelBinarizer().fit(df["zipcode"])
trainCategorical = zipBinarizer.transform(trainAttrX["zipcode"])
testCategorical = zipBinarizer.transform(testAttrX["zipcode"])

# construct our training and testing data points by concatenating
# the categorical features with the continuous features
trainAttrX = np.hstack([trainCategorical, trainContinuous])
testAttrX = np.hstack([testCategorical, testContinuous])

# %%
dim = trainAttrX.shape[1] #10

# define our MLP network
inp = keras.Input(shape=(dim,))
x = Dense(8, activation="relu")(inp)
out = Dense(4, activation="relu")(x)

mlp = keras.Model(inp, out)

# %%
from keras import Model, Input
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dense, Flatten, Dropout
from keras.layers import BatchNormalization

width, height, depth = 64, 64, 3
filters=(16, 32, 64)
# initialize the input shape and channel dimension, assuming
# TensorFlow/channels-last ordering
inputShape = (height, width, depth)

# define the model input
inputs = Input(shape=inputShape)

# loop over the number of filters
for (i, f) in enumerate(filters):
    # if this is the first CONV layer then set the input
    # appropriately
    if i == 0:
        x = inputs

    # CONV => RELU => BN => POOL
    x = Conv2D(f, (3, 3), padding="same")(x)
    x = Activation("relu")(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

# flatten the volume, then FC => RELU => BN => DROPOUT
x = Flatten()(x)
x = Dense(16)(x)
x = Activation("relu")(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

# apply another FC layer, this one to match the number of nodes
# coming out of the MLP
x = Dense(4)(x)
x = Activation("relu")(x)

# construct the CNN
cnn = Model(inputs, x)

# %%
from keras.layers import concatenate
# create the input to our final set of layers as the *output* of both
# the MLP and CNN
combinedInput = concatenate([mlp.output, cnn.output])

# our final FC layer head will have two dense layers, the final one
# being our regression head
x = Dense(4, activation="relu")(combinedInput)
x = Dense(1, activation="linear")(x)

model = Model([mlp.input, cnn.input], x)

# %%
model.compile(loss="mean_absolute_percentage_error", optimizer='adam')

# %%
keras.utils.plot_model(model, show_shapes=True, dpi=50)

# %%
# train the model
from  keras import callbacks

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=35)

model.fit(
    [trainAttrX, trainImagesX], trainY,
    validation_data=([testAttrX, testImagesX], testY),
    epochs=200, batch_size=8, callbacks=[reduce_lr])
# Out:
# Epoch 1/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 16s 156ms/step - loss: 270.3839 - val_loss: 70.9870 - learning_rate: 0.0010
# Epoch 2/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 138.2966 - val_loss: 88.7783 - learning_rate: 0.0010
# Epoch 3/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 87.1721 - val_loss: 83.8730 - learning_rate: 0.0010
# Epoch 4/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 73.6948 - val_loss: 82.2406 - learning_rate: 0.0010
# Epoch 5/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 98.8565 - val_loss: 78.7227 - learning_rate: 0.0010
# Epoch 6/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 74.4897 - val_loss: 78.1884 - learning_rate: 0.0010
# Epoch 7/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.7270 - val_loss: 77.3154 - learning_rate: 0.0010
# Epoch 8/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.6583 - val_loss: 73.8179 - learning_rate: 0.0010
# Epoch 9/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 58.9582 - val_loss: 74.4117 - learning_rate: 0.0010
# Epoch 10/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 54.9040 - val_loss: 64.8197 - learning_rate: 0.0010
# Epoch 11/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.6727 - val_loss: 65.7974 - learning_rate: 0.0010
# Epoch 12/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.8996 - val_loss: 57.1744 - learning_rate: 0.0010
# Epoch 13/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.2138 - val_loss: 70.0430 - learning_rate: 0.0010
# Epoch 14/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.1784 - val_loss: 47.1141 - learning_rate: 0.0010
# Epoch 15/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 43.5597 - val_loss: 40.7170 - learning_rate: 0.0010
# Epoch 16/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.5003 - val_loss: 42.7692 - learning_rate: 0.0010
# Epoch 17/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.1762 - val_loss: 38.7849 - learning_rate: 0.0010
# Epoch 18/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.2244 - val_loss: 36.4082 - learning_rate: 0.0010
# Epoch 19/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.1693 - val_loss: 36.4738 - learning_rate: 0.0010
# Epoch 20/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.6805 - val_loss: 36.2352 - learning_rate: 0.0010
# Epoch 21/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.8215 - val_loss: 33.7738 - learning_rate: 0.0010
# Epoch 22/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.5677 - val_loss: 32.4989 - learning_rate: 0.0010
# Epoch 23/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.9544 - val_loss: 36.6080 - learning_rate: 0.0010
# Epoch 24/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.8831 - val_loss: 32.2264 - learning_rate: 0.0010
# Epoch 25/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.7437 - val_loss: 34.4998 - learning_rate: 0.0010
# Epoch 26/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.2707 - val_loss: 31.0556 - learning_rate: 0.0010
# Epoch 27/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.3014 - val_loss: 31.6344 - learning_rate: 0.0010
# Epoch 28/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.7665 - val_loss: 28.7337 - learning_rate: 0.0010
# Epoch 29/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.6193 - val_loss: 29.1692 - learning_rate: 0.0010
# Epoch 30/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.4900 - val_loss: 30.8368 - learning_rate: 0.0010
# Epoch 31/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.4550 - val_loss: 32.6963 - learning_rate: 0.0010
# Epoch 32/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.0308 - val_loss: 29.2196 - learning_rate: 0.0010
# Epoch 33/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.8603 - val_loss: 26.1470 - learning_rate: 0.0010
# Epoch 34/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.5140 - val_loss: 27.7557 - learning_rate: 0.0010
# Epoch 35/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.7028 - val_loss: 26.6480 - learning_rate: 0.0010
# Epoch 36/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.2368 - val_loss: 25.0667 - learning_rate: 0.0010
# Epoch 37/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.1811 - val_loss: 27.1438 - learning_rate: 0.0010
# Epoch 38/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.3384 - val_loss: 24.9963 - learning_rate: 0.0010
# Epoch 39/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.8682 - val_loss: 24.6109 - learning_rate: 0.0010
# Epoch 40/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.0176 - val_loss: 25.5715 - learning_rate: 0.0010
# Epoch 41/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.9043 - val_loss: 27.6163 - learning_rate: 0.0010
# Epoch 42/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.1103 - val_loss: 24.7875 - learning_rate: 0.0010
# Epoch 43/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.7193 - val_loss: 25.3615 - learning_rate: 0.0010
# Epoch 44/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.8863 - val_loss: 23.9243 - learning_rate: 0.0010
# Epoch 45/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.7003 - val_loss: 25.8479 - learning_rate: 0.0010
# Epoch 46/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.1005 - val_loss: 26.4890 - learning_rate: 0.0010
# Epoch 47/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.9725 - val_loss: 23.1272 - learning_rate: 0.0010
# Epoch 48/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.8867 - val_loss: 24.2167 - learning_rate: 0.0010
# Epoch 49/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.7951 - val_loss: 24.4977 - learning_rate: 0.0010
# Epoch 50/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.3120 - val_loss: 23.0919 - learning_rate: 0.0010
# Epoch 51/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.7132 - val_loss: 22.5100 - learning_rate: 0.0010
# Epoch 52/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.8726 - val_loss: 23.2972 - learning_rate: 0.0010
# Epoch 53/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.0781 - val_loss: 23.3114 - learning_rate: 0.0010
# Epoch 54/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.7484 - val_loss: 23.1246 - learning_rate: 0.0010
# Epoch 55/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.7506 - val_loss: 26.5154 - learning_rate: 0.0010
# Epoch 56/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.1062 - val_loss: 22.6405 - learning_rate: 0.0010
# Epoch 57/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.4697 - val_loss: 21.9409 - learning_rate: 0.0010
# Epoch 58/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.2864 - val_loss: 22.6622 - learning_rate: 0.0010
# Epoch 59/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.9964 - val_loss: 23.3488 - learning_rate: 0.0010
# Epoch 60/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.1565 - val_loss: 22.5131 - learning_rate: 0.0010
# Epoch 61/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.6084 - val_loss: 21.3670 - learning_rate: 0.0010
# Epoch 62/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.6364 - val_loss: 23.3727 - learning_rate: 0.0010
# Epoch 63/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.7696 - val_loss: 23.1923 - learning_rate: 0.0010
# Epoch 64/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.4624 - val_loss: 21.9277 - learning_rate: 0.0010
# Epoch 65/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.6065 - val_loss: 22.1618 - learning_rate: 0.0010
# Epoch 66/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.4729 - val_loss: 21.2890 - learning_rate: 0.0010
# Epoch 67/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6788 - val_loss: 23.1275 - learning_rate: 0.0010
# Epoch 68/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.9138 - val_loss: 21.3582 - learning_rate: 0.0010
# Epoch 69/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.5153 - val_loss: 21.7934 - learning_rate: 0.0010
# Epoch 70/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.3629 - val_loss: 22.3219 - learning_rate: 0.0010
# Epoch 71/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.9772 - val_loss: 21.1273 - learning_rate: 0.0010
# Epoch 72/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.0020 - val_loss: 21.3469 - learning_rate: 0.0010
# Epoch 73/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.4642 - val_loss: 22.1373 - learning_rate: 0.0010
# Epoch 74/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 20.9065 - val_loss: 21.1115 - learning_rate: 0.0010
# Epoch 75/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.1065 - val_loss: 20.8983 - learning_rate: 0.0010
# Epoch 76/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.5895 - val_loss: 24.3185 - learning_rate: 0.0010
# Epoch 77/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.4353 - val_loss: 21.6195 - learning_rate: 0.0010
# Epoch 78/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.2118 - val_loss: 20.6758 - learning_rate: 0.0010
# Epoch 79/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.3831 - val_loss: 24.7177 - learning_rate: 0.0010
# Epoch 80/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.5601 - val_loss: 21.3176 - learning_rate: 0.0010
# Epoch 81/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.3821 - val_loss: 24.5649 - learning_rate: 0.0010
# Epoch 82/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.2431 - val_loss: 21.6945 - learning_rate: 0.0010
# Epoch 83/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.4215 - val_loss: 22.9055 - learning_rate: 0.0010
# Epoch 84/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.5533 - val_loss: 22.3594 - learning_rate: 0.0010
# Epoch 85/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.0527 - val_loss: 21.8201 - learning_rate: 0.0010
# Epoch 86/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.2877 - val_loss: 21.5545 - learning_rate: 0.0010
# Epoch 87/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.6985 - val_loss: 22.0807 - learning_rate: 0.0010
# Epoch 88/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.1354 - val_loss: 20.8606 - learning_rate: 0.0010
# Epoch 89/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.8669 - val_loss: 23.3631 - learning_rate: 0.0010
# Epoch 90/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.1621 - val_loss: 20.1237 - learning_rate: 0.0010
# Epoch 91/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.1185 - val_loss: 20.2137 - learning_rate: 0.0010
# Epoch 92/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.3387 - val_loss: 21.9489 - learning_rate: 0.0010
# Epoch 93/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.1585 - val_loss: 20.0918 - learning_rate: 0.0010
# Epoch 94/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.5182 - val_loss: 21.4617 - learning_rate: 0.0010
# Epoch 95/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.5125 - val_loss: 20.0624 - learning_rate: 0.0010
# Epoch 96/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.9961 - val_loss: 23.2761 - learning_rate: 0.0010
# Epoch 97/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.7000 - val_loss: 20.7467 - learning_rate: 0.0010
# Epoch 98/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.9736 - val_loss: 20.8479 - learning_rate: 0.0010
# Epoch 99/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.3647 - val_loss: 19.8818 - learning_rate: 0.0010
# Epoch 100/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6568 - val_loss: 20.6889 - learning_rate: 0.0010
# Epoch 101/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.7979 - val_loss: 19.9498 - learning_rate: 0.0010
# Epoch 102/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.6509 - val_loss: 20.7224 - learning_rate: 0.0010
# Epoch 103/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.8181 - val_loss: 20.5592 - learning_rate: 0.0010
# Epoch 104/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.2475 - val_loss: 20.5427 - learning_rate: 0.0010
# Epoch 105/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.0546 - val_loss: 21.7161 - learning_rate: 0.0010
# Epoch 106/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.9232 - val_loss: 20.6367 - learning_rate: 0.0010
# Epoch 107/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6791 - val_loss: 22.5803 - learning_rate: 0.0010
# Epoch 108/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.4986 - val_loss: 20.3803 - learning_rate: 0.0010
# Epoch 109/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.4671 - val_loss: 20.9287 - learning_rate: 0.0010
# Epoch 110/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.2624 - val_loss: 20.4550 - learning_rate: 0.0010
# Epoch 111/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.3201 - val_loss: 21.8950 - learning_rate: 0.0010
# Epoch 112/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.9466 - val_loss: 21.7118 - learning_rate: 0.0010
# Epoch 113/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.0890 - val_loss: 22.0802 - learning_rate: 0.0010
# Epoch 114/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.2385 - val_loss: 20.5012 - learning_rate: 0.0010
# Epoch 115/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.1204 - val_loss: 20.9452 - learning_rate: 0.0010
# Epoch 116/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.9728 - val_loss: 20.4184 - learning_rate: 0.0010
# Epoch 117/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.0709 - val_loss: 20.2077 - learning_rate: 0.0010
# Epoch 118/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.1778 - val_loss: 20.2081 - learning_rate: 0.0010
# Epoch 119/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.0399 - val_loss: 20.6606 - learning_rate: 0.0010
# Epoch 120/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1819 - val_loss: 28.1133 - learning_rate: 0.0010
# Epoch 121/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.0350 - val_loss: 23.9660 - learning_rate: 0.0010
# Epoch 122/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.2847 - val_loss: 21.5907 - learning_rate: 0.0010
# Epoch 123/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.1405 - val_loss: 20.5580 - learning_rate: 0.0010
# Epoch 124/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 16.1735 - val_loss: 20.3675 - learning_rate: 0.0010
# Epoch 125/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.2711 - val_loss: 20.7020 - learning_rate: 0.0010
# Epoch 126/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.1858 - val_loss: 21.3288 - learning_rate: 0.0010
# Epoch 127/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.3455 - val_loss: 23.1120 - learning_rate: 0.0010
# Epoch 128/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.5486 - val_loss: 21.1962 - learning_rate: 0.0010
# Epoch 129/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.0725 - val_loss: 22.9873 - learning_rate: 0.0010
# Epoch 130/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.3793 - val_loss: 20.8864 - learning_rate: 0.0010
# Epoch 131/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.4777 - val_loss: 21.9756 - learning_rate: 0.0010
# Epoch 132/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.6847 - val_loss: 20.8782 - learning_rate: 0.0010
# Epoch 133/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.9702 - val_loss: 20.4246 - learning_rate: 0.0010
# Epoch 134/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.7426 - val_loss: 19.5368 - learning_rate: 0.0010
# Epoch 135/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.9807 - val_loss: 22.5147 - learning_rate: 0.0010
# Epoch 136/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.0278 - val_loss: 19.5068 - learning_rate: 0.0010
# Epoch 137/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.7876 - val_loss: 20.9532 - learning_rate: 0.0010
# Epoch 138/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.4853 - val_loss: 20.9869 - learning_rate: 0.0010
# Epoch 139/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0298 - val_loss: 19.7367 - learning_rate: 0.0010
# Epoch 140/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.1410 - val_loss: 23.4551 - learning_rate: 0.0010
# Epoch 141/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.4316 - val_loss: 20.0603 - learning_rate: 0.0010
# Epoch 142/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.2583 - val_loss: 23.6512 - learning_rate: 0.0010
# Epoch 143/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.7164 - val_loss: 20.1617 - learning_rate: 0.0010
# Epoch 144/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.4464 - val_loss: 22.2356 - learning_rate: 0.0010
# Epoch 145/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.6795 - val_loss: 20.2883 - learning_rate: 0.0010
# Epoch 146/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.4569 - val_loss: 21.4175 - learning_rate: 0.0010
# Epoch 147/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.7747 - val_loss: 19.9177 - learning_rate: 0.0010
# Epoch 148/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.0908 - val_loss: 22.1093 - learning_rate: 0.0010
# Epoch 149/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.9811 - val_loss: 22.7504 - learning_rate: 0.0010
# Epoch 150/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.9665 - val_loss: 20.1788 - learning_rate: 0.0010
# Epoch 151/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4056 - val_loss: 19.6585 - learning_rate: 0.0010
# Epoch 152/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.0805 - val_loss: 21.2184 - learning_rate: 0.0010
# Epoch 153/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.4111 - val_loss: 20.6084 - learning_rate: 0.0010
# Epoch 154/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.1166 - val_loss: 20.0534 - learning_rate: 0.0010
# Epoch 155/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.3289 - val_loss: 20.5066 - learning_rate: 0.0010
# Epoch 156/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.5373 - val_loss: 21.0282 - learning_rate: 0.0010
# Epoch 157/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.5851 - val_loss: 20.8606 - learning_rate: 0.0010
# Epoch 158/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.5520 - val_loss: 20.6901 - learning_rate: 0.0010
# Epoch 159/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.7870 - val_loss: 20.0103 - learning_rate: 0.0010
# Epoch 160/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.7940 - val_loss: 20.2591 - learning_rate: 0.0010
# Epoch 161/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.2563 - val_loss: 21.0084 - learning_rate: 0.0010
# Epoch 162/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.5860 - val_loss: 21.9044 - learning_rate: 0.0010
# Epoch 163/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.0222 - val_loss: 20.4365 - learning_rate: 0.0010
# Epoch 164/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.3684 - val_loss: 20.5643 - learning_rate: 0.0010
# Epoch 165/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.2218 - val_loss: 19.8535 - learning_rate: 0.0010
# Epoch 166/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.9580 - val_loss: 22.4943 - learning_rate: 0.0010
# Epoch 167/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.3227 - val_loss: 20.0443 - learning_rate: 0.0010
# Epoch 168/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.0499 - val_loss: 19.5761 - learning_rate: 0.0010
# Epoch 169/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1724 - val_loss: 20.9538 - learning_rate: 0.0010
# Epoch 170/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.3011 - val_loss: 23.0971 - learning_rate: 0.0010
# Epoch 171/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.7230 - val_loss: 19.8674 - learning_rate: 0.0010
# Epoch 172/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.6961 - val_loss: 20.5068 - learning_rate: 1.0000e-04
# Epoch 173/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.4105 - val_loss: 20.2309 - learning_rate: 1.0000e-04
# Epoch 174/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.9388 - val_loss: 19.5448 - learning_rate: 1.0000e-04
# Epoch 175/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.6647 - val_loss: 19.4654 - learning_rate: 1.0000e-04
# Epoch 176/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.3600 - val_loss: 19.4631 - learning_rate: 1.0000e-04
# Epoch 177/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.1812 - val_loss: 19.4465 - learning_rate: 1.0000e-04
# Epoch 178/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.1949 - val_loss: 19.4224 - learning_rate: 1.0000e-04
# Epoch 179/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.5833 - val_loss: 19.2722 - learning_rate: 1.0000e-04
# Epoch 180/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.7808 - val_loss: 19.4677 - learning_rate: 1.0000e-04
# Epoch 181/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.6875 - val_loss: 19.3830 - learning_rate: 1.0000e-04
# Epoch 182/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.4352 - val_loss: 19.2566 - learning_rate: 1.0000e-04
# Epoch 183/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.0855 - val_loss: 19.2865 - learning_rate: 1.0000e-04
# Epoch 184/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.3250 - val_loss: 19.1101 - learning_rate: 1.0000e-04
# Epoch 185/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.7513 - val_loss: 19.5985 - learning_rate: 1.0000e-04
# Epoch 186/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.8966 - val_loss: 19.2184 - learning_rate: 1.0000e-04
# Epoch 187/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.9082 - val_loss: 19.3706 - learning_rate: 1.0000e-04
# Epoch 188/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.7447 - val_loss: 19.5946 - learning_rate: 1.0000e-04
# Epoch 189/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.2831 - val_loss: 19.1857 - learning_rate: 1.0000e-04
# Epoch 190/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.1575 - val_loss: 19.5174 - learning_rate: 1.0000e-04
# Epoch 191/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.4141 - val_loss: 19.3669 - learning_rate: 1.0000e-04
# Epoch 192/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.5533 - val_loss: 19.5407 - learning_rate: 1.0000e-04
# Epoch 193/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.4527 - val_loss: 19.6201 - learning_rate: 1.0000e-04
# Epoch 194/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.4865 - val_loss: 19.5961 - learning_rate: 1.0000e-04
# Epoch 195/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.9761 - val_loss: 19.6737 - learning_rate: 1.0000e-04
# Epoch 196/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.3201 - val_loss: 19.6564 - learning_rate: 1.0000e-04
# Epoch 197/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.9710 - val_loss: 19.7924 - learning_rate: 1.0000e-04
# Epoch 198/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.0059 - val_loss: 19.6108 - learning_rate: 1.0000e-04
# Epoch 199/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.1787 - val_loss: 19.5412 - learning_rate: 1.0000e-04
# Epoch 200/200
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.5027 - val_loss: 19.5657 - learning_rate: 1.0000e-04

# %%
# make predictions on the testing data
preds = model.predict([testAttrX, testImagesX])
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 382ms/step

# %%
# compute the difference between the *predicted* house prices and the
# *actual* house prices, then compute the percentage difference and
# the absolute percentage difference
diff = preds.flatten() - testY
percentDiff = (diff / testY) * 100
absPercentDiff = np.abs(percentDiff)

# compute the mean and standard deviation of the absolute percentage
# difference
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)

# finally, show some statistics on our model
locale.setlocale(locale.LC_ALL, "en_US.UTF-8")
print("[INFO] avg. house price: {}, std house price: {}".format(
    locale.currency(df["price"].mean(), grouping=True),
    locale.currency(df["price"].std(), grouping=True)))
print("[INFO] mean: {:.2f}%, std: {:.2f}%".format(mean, std))
# Out:
# [INFO] avg. house price: $533,388.27, std house price: $493,403.08
# [INFO] mean: 19.57%, std: 19.80%
